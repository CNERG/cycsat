# %%
from cycsat.prototypes.reactor import SampleReactor
from cycsat.archetypes import Facility, Rule

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
s = SampleReactor()
for feat in s.features[1:]:
    feat.rules.append(Rule(oper='near',target='sample cooling tower 1',value=100))
s.build()
s.plot()

# %%
s = SampleReactor()
for feat in s.features[1:]:
    feat.rules.append(Rule(oper='near',target='sample cooling tower 1',value=1000))
s.build()
s.plot()

# %%
s = SampleReactor()
for feat in s.features[1:]:
    feat.rules.append(Rule(oper='near',target='sample cooling tower 1',value=2000))
s.build()
s.plot()

# %%
s = SampleReactor()
for feat in s.features[1:]:
    feat.rules.append(Rule(oper='near',target='sample cooling tower 1',value=3000))
s.build()
s.plot()
